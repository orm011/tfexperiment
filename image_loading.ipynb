# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tensorflow as tf

# %%
import h5py
f = h5py.File('../h5data_random/miniplaces_256_train.h5')
imset = f.get('images')
labset = f.get('labels')
imset.shape, labset.shape

print(labset[0])
pyplot.imshow(imset[0])
# Out:
# 46

# %%
x = tf.image.adjust_contrast(imset[0:2], 0.5)
with tf.Session() as sess:
    out = sess.run(x)
    imshow(out[1])
